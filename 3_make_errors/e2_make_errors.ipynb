# %% [markdown]
# <a href="https://colab.research.google.com/github/tjtmddnjswkd/capstone/blob/jc/3_make_errors/e2_make_errors.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
try:
    from google.colab import drive
    drive.mount('/content/drive')
except:
    pass
# Out:
# Mounted at /content/drive

# %% [markdown]
# # 0.Data Load

# %%
import pandas as pd
import numpy as np
import json
import os
import re
from tqdm.notebook import tqdm

if os.path.exists(r"G:\내 드라이브\KB인턴관련"):
    gdrive_path = r"G:\내 드라이브\KB인턴관련"
else:
    gdrive_path = "/content/drive/MyDrive/KB인턴관련"

# %%
df = pd.read_csv(os.path.join(gdrive_path, "preprocessing/fin.csv"), encoding="euc-kr", index_col=0)
df.head()
# Out:
#   category           lawName  \
# 0       헌법  개성공업지구 지원에 관한 법률
# 2       헌법  개성공업지구 지원에 관한 법률
# 3       헌법  개성공업지구 지원에 관한 법률
# 4       헌법  개성공업지구 지원에 관한 법률
# 5       헌법  개성공업지구 지원에 관한 법률
#
#                                                  ENG  \
# 0  The purpose of this Act is to enhance inter-Ko...
# 2  The term "Gaeseong Industrial Complex" or "GIC...
# 3  The term "GIC developer" means a South Korean ...
# 4  The term "GIC management organ" means a corpor...
# 5  The term "local enterprise of the GIC" means a...
#
#                                                  KOR
# 0  이 법은 개성공업지구의 개발·운영의 지원 및 개성공업지구에 투자하거나 출입·체류하는...
# 2  "개성공업지구"란 남한과 북한 사이의 합의에 따라서 북한의 개성지역 일대에서 개발·...
# 3  "개성공업지구 개발업자"란 「남북교류협력에 관한 법률」에 따른 협력사업의 승인을 받...
# 4  "개성공업지구 관리기관"이란 개성공업지구의 관리·운영을 위하여 북한의 「개성공업지구...
# 5  "개성공업지구 현지기업"이란 남한주민이 「남북교류협력에 관한 법률」에 따른 협력사업...

# %% [markdown]
# # 1.Data Fiiltering

# %%
keyword_idx = df.loc[df.lawName.str.contains(r"은행|금융|보험|예금|적금|대출|외환|통화|화폐|환율")].index

# %%
tgk_idx = df.loc[df.category=="통화ㆍ국채ㆍ금융"].index

# %%
print(f"키워드: {len(keyword_idx)}\t통화/국채/금융: {len(tgk_idx)}")
print(f"키워드-통국금: {len(list(set(keyword_idx)-set(tgk_idx)))}")
print(f"통국금-키워드: {len(list(set(tgk_idx)-set(keyword_idx)))}")
print(f"전체:  {len(list(set(keyword_idx).union(set(tgk_idx))))}")
# Out:
# 키워드: 16712	통화/국채/금융: 16004
# 키워드-통국금: 4681
# 통국금-키워드: 3973
# 전체:  20685

# %%
df_samp = df.loc[list(set(keyword_idx).union(set(tgk_idx)))].drop(index=[403163], axis=0)
df_samp
# Out:
#         category                              lawName  \
# 547121        노동  고용보험 및 산업재해보상보험의 보험료징수 등에 관한 법률 시행령
# 547123        노동  고용보험 및 산업재해보상보험의 보험료징수 등에 관한 법률 시행령
# 547124        노동  고용보험 및 산업재해보상보험의 보험료징수 등에 관한 법률 시행령
# 547125        노동  고용보험 및 산업재해보상보험의 보험료징수 등에 관한 법률 시행령
# 547126        노동  고용보험 및 산업재해보상보험의 보험료징수 등에 관한 법률 시행령
# ...          ...                                  ...
# 78005   통화ㆍ국채ㆍ금융                                  국채법
# 78006   통화ㆍ국채ㆍ금융                                  국채법
# 78007   통화ㆍ국채ㆍ금융                                  국채법
# 406361  통화ㆍ국채ㆍ금융                          신용협동조합법 시행령
# 406362  통화ㆍ국채ㆍ금융                          신용협동조합법 시행령
#
#                                                       ENG  \
# 547121  Where the average monthly remuneration of each...
# 547123  Where the amount of monthly remuneration of ea...
# 547124  "Where any ground prescribed by Presidential D...
# 547125  The standard remuneration under Article 3 (2) ...
# 547126  Where an artist falls under any of the followi...
# ...                                                   ...
# 78005   Where necessary to properly issue and manage S...
# 78006   Any person requested to provide materials rela...
# 78007   Where necessary to formulate and carry out pol...
# 406361  Notwithstanding paragraph (3), a workplace cre...
# 406362  When providing the welfare services under para...
#
#                                                       KOR
# 547121  예술인[「고용보험법」 제77조의2제2항제2호 단서에 따른 단기예술인(이하 "단기예술...
# 547123  노무제공자[「고용보험법」 제77조의6제2항제2호 단서에 따른 단기노무제공자(이하 "...
# 547124  법 제3조제1항에서 "대통령령으로 정하는 사유에 해당하는 경우"란 다음 각 호의 어...
# 547125  법 제3조제2항(법 제48조의2제8항제2호 및 제48조의3제8항제2호에서 준용하는 ...
# 547126  예술인이 다음 각 호의 어느 하나에 해당하는 경우 법 제48조의2제8항제2호에서 준...
# ...                                                   ...
# 78005   기획재정부장관은 국채의 발행과 관리를 적절하게 하기 위하여 필요한 경우에는 관계 중...
# 78006   제1항에 따라 국채 관련 자료의 제출을 요청받은 자는 특별한 사유가 없으면 요청에 ...
# 78007   기획재정부장관은 국채시장에 관한 정책의 수립·운영에 필요한 경우에는 관계 중앙행정기...
# 406361  제3항의 규정에 불구하고 제12조제1항제2호의 직장조합 및 동항제3호 라목의 단체조...
# 406362  조합이 제1항의 규정에 의한 복지사업을 실시하는 경우에는 이용자에게 비용을 부담시킬...
#
# [20684 rows x 4 columns]

# %%
df_samp["curHyp"] = df_samp.KOR.values
df_samp["errors"] = [[] for _ in range(df_samp.shape[0])]
# df_samp.iloc[:, 2:4]

# %%
def remake_df():
    result = df.loc[list(set(keyword_idx).union(set(tgk_idx)))]
    result["curHyp"] = result.KOR.values
    result["errors"] = [[] for _ in range(result.shape[0])]
    return result.drop(index=[403163], axis=0)

def random_df(dfs, ratio):
    np.random.seed(10)
    return dfs.loc[np.random.choice(dfs.index, int(dfs.shape[0]*ratio), False), :]

def random_index(srs, ratio):
    np.random.seed(10)
    return np.random.choice(srs.index, int(srs.shape[0]*ratio), False)

# %% [markdown]
# # 2.품사 태깅

# %%
from kiwipiepy import Kiwi

kiwi = Kiwi(num_workers=0, model_type='sbg')
kiwi_tokens = df_samp.KOR.apply(lambda x: kiwi.tokenize(x))
kiwi_tokens
# Out:
# 547121    [(예술인, NNG, 0, 3), ([, SSO, 3, 1), (「, SSO, 4,...
# 547123    [(노무, NNG, 0, 2), (제공자, NNG, 2, 3), ([, SSO, 5...
# 547124    [(법, NNG, 0, 1), (제, XPN, 2, 1), (3, SN, 3, 1)...
# 547125    [(법, NNG, 0, 1), (제, XPN, 2, 1), (3, SN, 3, 1)...
# 547126    [(예술, NNG, 0, 2), (이, VCP, 2, 1), (ᆫ, ETM, 2, ...
#                                 ...
# 78005     [(기획, NNG, 0, 2), (재정부, NNG, 2, 3), (장관, NNG, ...
# 78006     [(제, XPN, 0, 1), (1, SN, 1, 1), (항, NNG, 2, 1)...
# 78007     [(기획, NNG, 0, 2), (재정부, NNG, 2, 3), (장관, NNG, ...
# 406361    [(제, XPN, 0, 1), (3, SN, 1, 1), (항, NNG, 2, 1)...
# 406362    [(조합, NNG, 0, 2), (이, JKS, 2, 1), (제, XPN, 4, ...
# Name: KOR, Length: 20685, dtype: object

# %%
def count_tag(tokens):
    token_dict = dict()
    for token in tokens:
        try:
            token_dict[token.tag].append(token.form)
        except:
            token_dict[token.tag] = [token.form]
    return token_dict

# %%
count_tokens = kiwi_tokens.apply(count_tag)
count_tokens
# Out:
# 547121    {'NNG': ['예술인', '항', '단서', '단기', '예술인', '이하', ...
# 547123    {'NNG': ['노무', '제공자', '항', '단서', '단기', '노무', '...
# 547124    {'NNG': ['법', '항', '대통령령', '사유', '해당', '경우', '...
# 547125    {'NNG': ['법', '항', '법', '항', '항', '준용', '경우', ...
# 547126    {'NNG': ['예술', '다음', '호의', '해당', '경우', '법', '항...
#                                 ...
# 78005     {'NNG': ['기획', '재정부', '장관', '국채', '발행', '관리', ...
# 78006     {'XPN': ['제'], 'SN': ['1'], 'NNG': ['항', '국채',...
# 78007     {'NNG': ['기획', '재정부', '장관', '국채', '시장', '정책', ...
# 406361    {'XPN': ['제', '제', '제', '제', '제'], 'SN': ['3',...
# 406362    {'NNG': ['조합', '항', '규정', '복지', '사업', '실시', '경...
# Name: KOR, Length: 20685, dtype: object

# %%
nng_dict = dict()
for tokens in count_tokens.apply(lambda x: x["NNG"]):
    for t in tokens:
        try:
            nng_dict[t] += 1
        except:
            nng_dict[t] = 1
len(nng_dict.keys())
# Out:
# 3703

# %% [markdown]
# # 3.Error 생성

# %% [markdown]
# ## 3.1.Major - Omission (고유명사 생략)

# %%
def find_nnp_tokens(tokens):
    nnp_tokens = []
    for token in tokens:
        if token.tag == "NNP":
            nnp_tokens.append((token.form, token.start, token.end))
    return nnp_tokens

nnp_info = kiwi_tokens.apply(find_nnp_tokens)
nnp_info
# Out:
# 547121    [(고용보험법, 5, 10)]
# 547123    [(고용보험법, 7, 12)]
# 547124                  []
# 547125                  []
# 547126                  []
#                 ...
# 78005     [(한국은행, 56, 60)]
# 78006                   []
# 78007                   []
# 406361                  []
# 406362                  []
# Name: KOR, Length: 20685, dtype: object

# %%
change_val = nnp_info.loc[nnp_info.apply(len) > 0].apply(lambda x: sorted(x, key=lambda e: len(e[0]), reverse=True)[0])
change_val
# Out:
# 547121        (고용보험법, 5, 10)
# 547123        (고용보험법, 7, 12)
# 394199       (특별자치시, 65, 70)
# 394206          (관보, 65, 67)
# 394213        (경제자유구역, 0, 6)
#                  ...
# 416408      (주주총회, 105, 109)
# 194518    (산업재해보상보험, 25, 33)
# 78003          (한국은행, 8, 12)
# 78004           (한국은행, 0, 4)
# 78005         (한국은행, 56, 60)
# Name: KOR, Length: 3040, dtype: object

# %%
ch3 = change_val[change_val.apply(lambda x: len(x[0])) > 3]
drop_idx = ch3.loc[ch3.apply(lambda x: len(x[0].split("·")))>1].index.to_list()

# %%
ch3.loc[ch3.apply(lambda x: len(x[0].split("·")))>1]
# Out:
# Series([], Name: KOR, dtype: object)

# %%
df_samp = remake_df()

# temp = df_samp[["curHyp", "errors"]].copy(deep=True)
# temp

# %%
def critical_omission(ch_srs, df_local):
    result = df_local
    for i in ch_srs.index:
        del_word, start, end = ch_srs.loc[i]
        cur_hyp = result.loc[i, "curHyp"]
        forward = cur_hyp[:start]
        backward = cur_hyp[start:]
        split_back = backward.split(" ")
        del_unit = split_back[0]
        back_mod = " ".join(split_back[1:])
        try:
            if cur_hyp[end]== "(": continue
            elif start==0:
                result.loc[i, "curHyp"] = (forward+back_mod).strip(" ")
                result.loc[i, "errors"].append({"severity":"major", "start_idx":0, "text":del_unit, "type":"omission"})
            elif cur_hyp[start-1] == '"' or cur_hyp[start-1]=='「' :
                continue
            else:
                result.loc[i, "curHyp"] = (forward+back_mod).strip(" ")
                result.loc[i, "errors"].append({"severity":"major", "start_idx":start, "text":del_unit, "type":"omission"})
        except:
            pass

    return result

# %%
# d_index= random_index(temp, 0.1)
co_case = critical_omission(ch3.drop(index=[403163]), df_samp)

# %%
ch3.loc[547121]
# Out:
# ('고용보험법', 5, 10)

# %%
df_samp.loc[394372, "KOR"]
# Out:
# '경제자유구역(경제자유구역개발계획이 수립된 지역만 해당한다)에 있는 국가 또는 지방자치단체 소유의 토지로서 개발사업에 필요한 토지는 개발사업 외의 목적으로 매각하거나 양도할 수 없다.'

# %%
df_samp.loc[co_case.errors.apply(len)>0]
# Out:
#         category                  lawName  \
# 394199  통화ㆍ국채ㆍ금융  경제자유구역의 지정 및 운영에 관한 특별법
# 394213  통화ㆍ국채ㆍ금융  경제자유구역의 지정 및 운영에 관한 특별법
# 394231  통화ㆍ국채ㆍ금융  경제자유구역의 지정 및 운영에 관한 특별법
# 394249  통화ㆍ국채ㆍ금융  경제자유구역의 지정 및 운영에 관한 특별법
# 394310  통화ㆍ국채ㆍ금융  경제자유구역의 지정 및 운영에 관한 특별법
# ...          ...                      ...
# 416408  통화ㆍ국채ㆍ금융   자본시장과 금융투자업에 관한 법률 시행령
# 194518        노동            산업재해보상보험법 시행령
# 78003   통화ㆍ국채ㆍ금융                      국채법
# 78004   통화ㆍ국채ㆍ금융                      국채법
# 78005   통화ㆍ국채ㆍ금융                      국채법
#
#                                                       ENG  \
# 394199  A Mayor/Do Governor may request the Minister o...
# 394213  Feasibility of securing sites and infrastructu...
# 394231  Matters concerning the supply of exclusive lan...
# 394249  When any free economic zone is designated or m...
# 394310  Where a free economic zone designated pursuant...
# ...                                                   ...
# 416408  Where a person performs an act falling under a...
# 194518  The Industrial Accident Compensation Insurance...
# 78003   Article 36 (4) and (5) of the Management of th...
# 78004   The Governor of the Bank of Korea shall file a...
# 78005   Where necessary to properly issue and manage S...
#
#                                                       KOR  \
# 394199  시·도지사는 산업통상자원부장관에게 경제자유구역의 지정을 요청할 수 있다. 다만, 대...
# 394213  경제자유구역의 개발에 필요한 부지와 광역교통망·정보통신망·용수·전력 등 기반시설의 ...
# 394231  외국인투자기업, 국내복귀기업, 첨단기술 및 첨단제품 투자 기업, 핵심전략산업 투자 ...
# 394249  경제자유구역의 지정 또는 변경이 있은 때에는 그 경제자유구역개발계획의 내용에 따라 ...
# 394310  산업통상자원부장관은 제4조에 따라 지정된 경제자유구역이 다음 각 호의 어느 하나에 ...
# ...                                                   ...
# 416408  신문·방송·잡지 등 불특정 다수인에 대한 광고를 통하여 법 제152조제2항 각 호의...
# 194518  이 영 시행 당시 종전의 규정에 따라 설치된 산업재해보상보험심의위원회, 정책전문위원...
# 78003   제1항에 따라 한국은행이 처리하는 국채에 관한 사무 중 국채 발행에 따라 수입되는 ...
# 78004   한국은행 총재는 제15조에 따른 국채에 관한 사무의 처리 내용을 기획재정부령으로 정...
# 78005   기획재정부장관은 국채의 발행과 관리를 적절하게 하기 위하여 필요한 경우에는 관계 중...
#
#                                                    curHyp  \
# 394199  시·도지사는 산업통상자원부장관에게 경제자유구역의 지정을 요청할 수 있다. 다만, 대...
# 394213    개발에 필요한 부지와 광역교통망·정보통신망·용수·전력 등 기반시설의 확보가 가능할 것
# 394231  외국인투자기업, 국내복귀기업, 첨단기술 및 첨단제품 투자 기업, 핵심전략산업 투자 ...
# 394249  지정 또는 변경이 있은 때에는 그 경제자유구역개발계획의 내용에 따라 다음 각 호의 ...
# 394310  산업통상자원부장관은 제4조에 따라 지정된 다음 각 호의 어느 하나에 해당하는 경우에...
# ...                                                   ...
# 416408  신문·방송·잡지 등 불특정 다수인에 대한 광고를 통하여 법 제152조제2항 각 호의...
# 194518  이 영 시행 당시 종전의 규정에 따라 설치된 정책전문위원회 및 요양전문위원회는 각각...
# 78003   제1항에 따라 처리하는 국채에 관한 사무 중 국채 발행에 따라 수입되는 자금과 국채...
# 78004   총재는 제15조에 따른 국채에 관한 사무의 처리 내용을 기획재정부령으로 정하는 바에...
# 78005   기획재정부장관은 국채의 발행과 관리를 적절하게 하기 위하여 필요한 경우에는 관계 중...
#
#                                                    errors
# 394199  [{'severity': 'major', 'start_idx': 65, 'text'...
# 394213  [{'severity': 'major', 'start_idx': 0, 'text':...
# 394231  [{'severity': 'major', 'start_idx': 120, 'text...
# 394249  [{'severity': 'major', 'start_idx': 0, 'text':...
# 394310  [{'severity': 'major', 'start_idx': 23, 'text'...
# ...                                                   ...
# 416408  [{'severity': 'major', 'start_idx': 105, 'text...
# 194518  [{'severity': 'major', 'start_idx': 25, 'text'...
# 78003   [{'severity': 'major', 'start_idx': 8, 'text':...
# 78004   [{'severity': 'major', 'start_idx': 0, 'text':...
# 78005   [{'severity': 'major', 'start_idx': 56, 'text'...
#
# [2089 rows x 6 columns]

# %% [markdown]
# ## 3.2.Minor - Omission (매우를 생략해서 의미가 약간 변질되는 경우)

# %%
rindex1 = random_df(df_samp.loc[(df_samp.errors.apply(len) == 0)],0.2).index

# %%
tag_name = "NNB"
set(count_tokens[rindex1].apply(lambda x: x[tag_name] if tag_name in x.keys() else []).sum())

# %%
a = "심신의 장애로 직무를 집행하는 것이 매우 곤란하게 된 경우"
a[:20]+a[23:]
# Out:
# '심신의 장애로 직무를 집행하는 것이 곤란하게 된 경우'

# %%
very_idx = df_samp.loc[(df_samp.KOR.str.contains("매우")) & (df_samp.errors.apply(lambda x: len(x))==0)].index
for i in very_idx:
    cur_hyp = df_samp.loc[i, "curHyp"]
    start = cur_hyp.find("매우")
    new_hyp = cur_hyp[:start]+cur_hyp[start+3: ]
    df_samp.loc[i, "curHyp"] = new_hyp
    df_samp.loc[i, "errors"].append({"severity":"minor", "start_idx":start, "text":"매우", "type":"omission"})
# very_df.KOR.apply(lambda x: x.find("매우"))

# %%
df_samp.loc[very_idx, :]
# Out:
#         category                      lawName  \
# 396497  통화ㆍ국채ㆍ금융           금융위원회의 설치 등에 관한 법률
# 396605  통화ㆍ국채ㆍ금융           금융위원회의 설치 등에 관한 법률
# 404615  통화ㆍ국채ㆍ금융     신용정보의 이용 및 보호에 관한 법률 시행령
# 81406   통화ㆍ국채ㆍ금융  대부업 등의 등록 및 금융이용자 보호에 관한 법률
# 82739   통화ㆍ국채ㆍ금융                       예금자보호법
# 82934   통화ㆍ국채ㆍ금융                       예금자보호법
# 422286  통화ㆍ국채ㆍ금융                    한국주택금융공사법
# 105888  상업ㆍ무역ㆍ공업                        무역보험법
#
#                                                       ENG  \
# 396497  Where it has become significantly difficult fo...
# 396605  The Governor may request the reconsideration o...
# 404615  "Ground prescribed by Presidential Decree" in ...
# 81406   Where a reasonable ground exists to conclude t...
# 82739   The term "insolvency-threatened financial comp...
# 82934   Before the Government conducts gratuitous tran...
# 422286  Where he or she is unable to perform his or he...
# 105888  Where it has become impracticable or impossibl...
#
#                                                       KOR  \
# 396497                   심신의 장애로 직무를 집행하는 것이 매우 곤란하게 된 경우
# 396605  원장은 조정위원회의 의결사항이 위법하거나 공익에 비추어 매우 부당하다고 판단하면 재...
# 404615  법 제14조제1항 단서에서 "대통령령으로 정하는 사유"란 신용정보회사, 본인신용정보...
# 81406         의견청취가 매우 어렵거나 명백히 불필요하다고 인정되는 상당한 이유가 있는 경우
# 82739   "부실우려금융회사"란 재무구조가 취약하여 부실금융회사가 될 가능성이 매우 크다고 제...
# 82934   정부는 제1항에 따른 무상 양여를 하기 전에 국무회의의 심의 및 대통령의 승인을 거...
# 422286                      심신의 장애로 직무를 수행하기가 매우 어렵게 된 경우
# 105888           심신장애로 직무를 수행하는 것이 매우 곤란하게 되거나 불가능하게 된 경우
#
#                                                    curHyp  \
# 396497                      심신의 장애로 직무를 집행하는 것이 곤란하게 된 경우
# 396605  원장은 조정위원회의 의결사항이 위법하거나 공익에 비추어 부당하다고 판단하면 재의를 ...
# 404615  법 제14조제1항 단서에서 "대통령령으로 정하는 사유"란 신용정보회사, 본인신용정보...
# 81406            의견청취가 어렵거나 명백히 불필요하다고 인정되는 상당한 이유가 있는 경우
# 82739   "부실우려금융회사"란 재무구조가 취약하여 부실금융회사가 될 가능성이 크다고 제8조에...
# 82934   정부는 제1항에 따른 무상 양여를 하기 전에 국무회의의 심의 및 대통령의 승인을 거...
# 422286                         심신의 장애로 직무를 수행하기가 어렵게 된 경우
# 105888              심신장애로 직무를 수행하는 것이 곤란하게 되거나 불가능하게 된 경우
#
#                                                    errors
# 396497  [{'severity': 'minor', 'start_idx': 20, 'text'...
# 396605  [{'severity': 'minor', 'start_idx': 31, 'text'...
# 404615  [{'severity': 'minor', 'start_idx': 139, 'text...
# 81406   [{'severity': 'minor', 'start_idx': 6, 'text':...
# 82739   [{'severity': 'minor', 'start_idx': 38, 'text'...
# 82934   [{'severity': 'minor', 'start_idx': 90, 'text'...
# 422286  [{'severity': 'minor', 'start_idx': 18, 'text'...
# 105888  [{'severity': 'minor', 'start_idx': 18, 'text'...

# %% [markdown]
# ## 3.3.Neutral - Mis-translation(사소한 번역 오류)

# %%
df_samp.loc[df_samp.curHyp.str.contains(r"달러|제곱미터|퍼센트")][["ENG", "curHyp"]]
# Out:
#                                                       ENG  \
# 394528  The amount of foreign investment to be investe...
# 399090  The fees for guarantee which the management in...
# 399094  The penalties for breach of contract which the...
# 77386   Where a development project under subparagraph...
# 77583   Notwithstanding paragraphs (1) and (2), the si...
# 77650   If the State and a local government sell any S...
# 77676   The price in an ordinary transaction in any fr...
# 77741   Each person who has been granted permission to...
# 408573  The limit of payment or receipt of amount that...
# 408782  Where a resident makes a direct payment of cos...
# 408809  Claims subject to filing a report on the curre...
# 408915  "Amount prescribed by Presidential Decree" in ...
# 417058  Equity capital worth at least one million U.S....
# 417060  The amount of assets managed as of the end of ...
# 408781  Where any payment for export not exceeding 50 ...
# 422833  A building with a total floor area of at least...
# 422844  A building used as a school under Article 2 of...
# 422850  A station or station facilities used as a stat...
# 519213  In cases of a member of a household without ho...
# 519215  In cases of a member of a household without ho...
#
#                                                    curHyp
# 394528            관광사업에 투자하려는 외국인투자 금액이 미합중국화폐 5억달러 이상일 것
# 399090  관리기관이 법 제11조의 규정에 의하여 받는 보증료는 보증한 금액에 보증료율을 곱하...
# 399094  관리기관이 법 제11조의2의 규정에 의하여 징수하는 위약금은 보증한 채무중 이행되지...
# 77386   법 제6조제1항제3호의2에 따른 단위개발사업지구(이하 "단위개발사업지구"라 한다) ...
# 77583   제1항 및 제2항에도 불구하고 「주택법」 제2조제6호에 따른 국민주택 규모 이하 주...
# 77650   법 제16조제6항에 따라 국가 및 지방자치단체가 개발사업시행자나 주요입주기업에 국유...
# 77676   법 제21조에 따라 경제자유구역에서 건당 10만 달러 이하의 경상거래에 따른 대가는...
# 77741   카지노업 허가를 받은 자는 영업개시 후 2년이 지난 날부터 30일 이내에 제20조의...
# 408573  소액해외송금업자가 취급할 수 있는 건당 지급 및 수령 범위는 각각 미화 5천달러를 ...
# 408782  거주자가 건당 미화 1만달러 이하의 경상거래에 따른 대가를 외국환업무취급기관등을 통...
# 408809  법 제20조제1항에 따라 비거주자에 대한 채권보유현황을 보고하여야 하는 대상은 미화...
# 408915     법 제29조제1항제4호에서 "대통령령으로 정하는 금액"이란 미화 3만달러를 말한다.
# 417058  미화 100만달러 이상으로서 금융위원회가 정하여 고시하는 금액 이상의 자기자본을 갖출 것
# 417060  직전 사업연도말 현재 운용자산규모(금융위원회가 정하여 고시하는 방법에 따라 계산한 ...
# 408781  계약 건당 미화 5만달러 이내의 수출대금을 기획재정부장관이 정하여 고시하는 기간을 ...
# 422833  「국유재산법」 제5조제1항제1호에 따른 부동산 중 연면적이 1천제곱미터 이상인 건물...
# 422844  「초·중등교육법」 제2조 및 「고등교육법」 제2조에 따른 학교로 사용하는 건물로서 ...
# 422850  「도시철도법」 제2조제3호가목에 따른 도시철도의 역사 및 역 시설로 사용하는 부분의...
# 519213  1세대무주택자의 경우: 보증금담보대출등을 받아 임차한 임차주택의 보증금 및 월세금액...
# 519215  1세대무주택자의 경우: 보증금담보대출등 금액의 합산액(상환한 금액은 제외한다)의 3...

# %%
dollor_index = df_samp.loc[df_samp.curHyp.str.contains(r"미[^☞]+달러")].index

d1, d2 = "미합중국화폐 ", "미화 "
for i in dollor_index:
    cur_hyp = df_samp.loc[i, "curHyp"]
    end=cur_hyp.find("달러")
    start = cur_hyp.find(d1)
    if start==-1:
        start = cur_hyp.find(d2)
        new_hyp = cur_hyp.replace(d2, "")
        new_hyp = new_hyp.replace("달러", " USD")
    else:
        new_hyp = cur_hyp.replace(d1, "")
        new_hyp = new_hyp.replace("달러", " USD")
    df_samp.loc[i, "curHyp"] = new_hyp
    df_samp.loc[i, "errors"].append({"severity":"neutral", "start_idx":start, "text":cur_hyp[start:end+2], "type":"mis-translation"})

# %%
df_samp.loc[dollor_index].iloc[:, 3:]
# Out:
#                                                       KOR  \
# 394528  경제자유구역에서의 관광사업에 투자하려는 외국인투자 금액이 미합중국화폐 5억달러 이상일 것
# 77741   카지노업 허가를 받은 자는 영업개시 후 2년이 지난 날부터 30일 이내에 제20조의...
# 408573  소액해외송금업자가 취급할 수 있는 건당 지급 및 수령 범위는 각각 미화 5천달러를 ...
# 408782  거주자가 건당 미화 1만달러 이하의 경상거래에 따른 대가를 외국환업무취급기관등을 통...
# 408809  법 제20조제1항에 따라 비거주자에 대한 채권보유현황을 보고하여야 하는 대상은 미화...
# 408915     법 제29조제1항제4호에서 "대통령령으로 정하는 금액"이란 미화 3만달러를 말한다.
# 417058  미화 100만달러 이상으로서 금융위원회가 정하여 고시하는 금액 이상의 자기자본을 갖출 것
# 417060  직전 사업연도말 현재 운용자산규모(금융위원회가 정하여 고시하는 방법에 따라 계산한 ...
# 408781  계약 건당 미화 5만달러 이내의 수출대금을 기획재정부장관이 정하여 고시하는 기간을 ...
#
#                                                    curHyp  \
# 394528                 관광사업에 투자하려는 외국인투자 금액이 5억 USD 이상일 것
# 77741   카지노업 허가를 받은 자는 영업개시 후 2년이 지난 날부터 30일 이내에 제20조의...
# 408573  소액해외송금업자가 취급할 수 있는 건당 지급 및 수령 범위는 각각 5천 USD를 한...
# 408782  거주자가 건당 1만 USD 이하의 경상거래에 따른 대가를 외국환업무취급기관등을 통하...
# 408809  법 제20조제1항에 따라 비거주자에 대한 채권보유현황을 보고하여야 하는 대상은 1만...
# 408915      법 제29조제1항제4호에서 "대통령령으로 정하는 금액"이란 3만 USD를 말한다.
# 417058   100만 USD 이상으로서 금융위원회가 정하여 고시하는 금액 이상의 자기자본을 갖출 것
# 417060  직전 사업연도말 현재 운용자산규모(금융위원회가 정하여 고시하는 방법에 따라 계산한 ...
# 408781  계약 건당 5만 USD 이내의 수출대금을 기획재정부장관이 정하여 고시하는 기간을 초...
#
#                                                    errors
# 394528  [{'severity': 'major', 'start_idx': 0, 'text':...
# 77741   [{'severity': 'major', 'start_idx': 58, 'text'...
# 408573  [{'severity': 'neutral', 'start_idx': 37, 'tex...
# 408782  [{'severity': 'neutral', 'start_idx': 8, 'text...
# 408809  [{'severity': 'neutral', 'start_idx': 44, 'tex...
# 408915  [{'severity': 'neutral', 'start_idx': 33, 'tex...
# 417058  [{'severity': 'neutral', 'start_idx': 0, 'text...
# 417060  [{'severity': 'neutral', 'start_idx': 55, 'tex...
# 408781  [{'severity': 'neutral', 'start_idx': 6, 'text...

# %%
percent_idx = df_samp.loc[df_samp.curHyp.str.contains("퍼센트")].iloc[:,3:].index

# %%
df_samp.loc[df_samp.curHyp.str.contains("퍼센트")].iloc[:,3:]
# Out:
#                                                       KOR  \
# 399090  관리기관이 법 제11조의 규정에 의하여 받는 보증료는 보증한 금액에 보증료율을 곱하...
# 399094  관리기관이 법 제11조의2의 규정에 의하여 징수하는 위약금은 보증한 채무중 이행되지...
# 77650   법 제16조제6항에 따라 국가 및 지방자치단체가 개발사업시행자나 주요입주기업에 국유...
# 519213  1세대무주택자의 경우: 보증금담보대출등을 받아 임차한 임차주택의 보증금 및 월세금액...
# 519215  1세대무주택자의 경우: 보증금담보대출등 금액의 합산액(상환한 금액은 제외한다)의 3...
#
#                                                    curHyp  \
# 399090  관리기관이 법 제11조의 규정에 의하여 받는 보증료는 보증한 금액에 보증료율을 곱하...
# 399094  관리기관이 법 제11조의2의 규정에 의하여 징수하는 위약금은 보증한 채무중 이행되지...
# 77650   법 제16조제6항에 따라 국가 및 지방자치단체가 개발사업시행자나 주요입주기업에 국유...
# 519213  1세대무주택자의 경우: 보증금담보대출등을 받아 임차한 임차주택의 보증금 및 월세금액...
# 519215  1세대무주택자의 경우: 보증금담보대출등 금액의 합산액(상환한 금액은 제외한다)의 3...
#
#                                                    errors
# 399090                                                 []
# 399094                                                 []
# 77650   [{'severity': 'major', 'start_idx': 47, 'text'...
# 519213                                                 []
# 519215                                                 []

# %%
for i in percent_idx:
    cur_hyp = df_samp.loc[i, "curHyp"]
    start = cur_hyp.find("퍼센트")
    new_hyp = cur_hyp.replace("퍼센트", "%")
    df_samp.loc[i, "curHyp"] = new_hyp
    df_samp.loc[i, "errors"].append({"severity":"neutral", "start_idx":start, "text":"퍼센트", "type":"mis-translation"})
df_samp.loc[percent_idx]
# Out:
#         category                      lawName  \
# 399090  통화ㆍ국채ㆍ금융             농림수산업자 신용보증법 시행령
# 399094  통화ㆍ국채ㆍ금융             농림수산업자 신용보증법 시행령
# 77650   통화ㆍ국채ㆍ금융  경제자유구역의 지정 및 운영에 관한 특별법 시행령
# 519213      사회복지                  국민건강보험법 시행령
# 519215      사회복지                  국민건강보험법 시행령
#
#                                                       ENG  \
# 399090  The fees for guarantee which the management in...
# 399094  The penalties for breach of contract which the...
# 77650   If the State and a local government sell any S...
# 519213  In cases of a member of a household without ho...
# 519215  In cases of a member of a household without ho...
#
#                                                       KOR  \
# 399090  관리기관이 법 제11조의 규정에 의하여 받는 보증료는 보증한 금액에 보증료율을 곱하...
# 399094  관리기관이 법 제11조의2의 규정에 의하여 징수하는 위약금은 보증한 채무중 이행되지...
# 77650   법 제16조제6항에 따라 국가 및 지방자치단체가 개발사업시행자나 주요입주기업에 국유...
# 519213  1세대무주택자의 경우: 보증금담보대출등을 받아 임차한 임차주택의 보증금 및 월세금액...
# 519215  1세대무주택자의 경우: 보증금담보대출등 금액의 합산액(상환한 금액은 제외한다)의 3...
#
#                                                    curHyp  \
# 399090  관리기관이 법 제11조의 규정에 의하여 받는 보증료는 보증한 금액에 보증료율을 곱하...
# 399094  관리기관이 법 제11조의2의 규정에 의하여 징수하는 위약금은 보증한 채무중 이행되지...
# 77650   법 제16조제6항에 따라 국가 및 지방자치단체가 개발사업시행자나 주요입주기업에 국유...
# 519213  1세대무주택자의 경우: 보증금담보대출등을 받아 임차한 임차주택의 보증금 및 월세금액...
# 519215  1세대무주택자의 경우: 보증금담보대출등 금액의 합산액(상환한 금액은 제외한다)의 3...
#
#                                                    errors
# 399090  [{'severity': 'neutral', 'start_idx': 75, 'tex...
# 399094  [{'severity': 'neutral', 'start_idx': 58, 'tex...
# 77650   [{'severity': 'major', 'start_idx': 47, 'text'...
# 519213  [{'severity': 'neutral', 'start_idx': 109, 'te...
# 519215  [{'severity': 'neutral', 'start_idx': 47, 'tex...

# %%
df_samp.loc[df_samp.errors.apply(lambda x: len(x))==0].shape[0]
# Out:
# 18576

# %% [markdown]
# ##3.4.Major - Omission (법령명을 생략하는 경우)

# %%
law_index = df_samp.loc[(df_samp.errors.apply(lambda x: len(x))==0)&(df_samp.KOR.str.contains("「"))].index

# %%
for i in law_index:
    cur_hyp = df_samp.loc[i, "curHyp"]
    start = cur_hyp.find("「")
    end = cur_hyp.find("」")
    addition_str = ""
    try:
        while cur_hyp[end+1]!=" ":
            addition_str += cur_hyp[end+1]
            end+=1
    except:
        pass

    df_samp.loc[i, "curHyp"] = cur_hyp[:start].rstrip()+" "+cur_hyp[end+1:].lstrip()
    df_samp.loc[i, "errors"].append({"severity":"major", "start_idx":start, "text":cur_hyp[start:end+1].strip(), "type":"omission"})

# %%
df_samp.loc[law_index]
# Out:
#         category                              lawName  \
# 547121        노동  고용보험 및 산업재해보상보험의 보험료징수 등에 관한 법률 시행령
# 547123        노동  고용보험 및 산업재해보상보험의 보험료징수 등에 관한 법률 시행령
# 394158  통화ㆍ국채ㆍ금융              경제자유구역의 지정 및 운영에 관한 특별법
# 394159  통화ㆍ국채ㆍ금융              경제자유구역의 지정 및 운영에 관한 특별법
# 394161  통화ㆍ국채ㆍ금융              경제자유구역의 지정 및 운영에 관한 특별법
# ...          ...                                  ...
# 194486        노동                        산업재해보상보험법 시행령
# 194490        노동                        산업재해보상보험법 시행령
# 194491        노동                        산업재해보상보험법 시행령
# 194492        노동                        산업재해보상보험법 시행령
# 194497        노동                        산업재해보상보험법 시행령
#
#                                                       ENG  \
# 547121  Where the average monthly remuneration of each...
# 547123  Where the amount of monthly remuneration of ea...
# 394158  The term "alien" means a person who falls unde...
# 394159  The term "foreign-invested enterprise" means a...
# 394161  The term "repatriating enterprise" means an en...
# ...                                                   ...
# 194486  Software engineers defined in subparagraph 10 ...
# 194490  Where the employer submits documents required ...
# 194491  Where the employer enters information on the o...
# 194492  Where the employer submits a plan to transport...
# 194497  The Minister of Employment and Labor or the Se...
#
#                                                       KOR  \
# 547121  예술인[「고용보험법」 제77조의2제2항제2호 단서에 따른 단기예술인(이하 "단기예술...
# 547123  노무제공자[「고용보험법」 제77조의6제2항제2호 단서에 따른 단기노무제공자(이하 "...
# 394158        "외국인"이란 「외국인투자 촉진법」 제2조제1항제1호에 해당하는 자를 말한다.
# 394159     "외국인투자기업"이란 「외국인투자 촉진법」 제2조제1항제6호에 따른 기업을 말한다.
# 394161  "국내복귀기업"이란 「해외진출기업의 국내복귀 지원에 관한 법률」 제7조에 따라 지원...
# ...                                                   ...
# 194486  「소프트웨어 진흥법」 제2조제3호의 소프트웨어사업에서 노무를 제공하는 같은 조 제1...
# 194490  「관세법」 제222조제1항 및 같은 법 시행령 제231조에 따라 세관장에게 보세운송...
# 194491  「물류정책기본법」 제29조의2제5항에 따라 위험물질운송차량의 소유자 정보 및 운전자...
# 194492  「화학물질관리법」제15조제3항에 따라 환경부장관에게 유해화학물질 운반계획서를 제출한 경우
# 194497  고용노동부장관 또는 공단(제19조에 따라 공단의 업무를 위탁받은 자를 포함한다)은 ...
#
#                                                    curHyp  \
# 547121  예술인[ 제77조의2제2항제2호 단서에 따른 단기예술인(이하 "단기예술인"이라 한다...
# 547123  노무제공자[ 제77조의6제2항제2호 단서에 따른 단기노무제공자(이하 "단기노무제공자...
# 394158                    "외국인"이란 제2조제1항제1호에 해당하는 자를 말한다.
# 394159                 "외국인투자기업"이란 제2조제1항제6호에 따른 기업을 말한다.
# 394161             "국내복귀기업"이란 제7조에 따라 지원대상으로 선정된 기업을 말한다.
# ...                                                   ...
# 194486   제2조제3호의 소프트웨어사업에서 노무를 제공하는 같은 조 제10호에 따른 소프트웨...
# 194490   제222조제1항 및 같은 법 시행령 제231조에 따라 세관장에게 보세운송업자 등록...
# 194491   제29조의2제5항에 따라 위험물질운송차량의 소유자 정보 및 운전자 정보 등을 위험...
# 194492                    따라 환경부장관에게 유해화학물질 운반계획서를 제출한 경우
# 194497  고용노동부장관 또는 공단(제19조에 따라 공단의 업무를 위탁받은 자를 포함한다)은 ...
#
#                                                    errors
# 547121  [{'severity': 'major', 'start_idx': 4, 'text':...
# 547123  [{'severity': 'major', 'start_idx': 6, 'text':...
# 394158  [{'severity': 'major', 'start_idx': 8, 'text':...
# 394159  [{'severity': 'major', 'start_idx': 12, 'text'...
# 394161  [{'severity': 'major', 'start_idx': 11, 'text'...
# ...                                                   ...
# 194486  [{'severity': 'major', 'start_idx': 0, 'text':...
# 194490  [{'severity': 'major', 'start_idx': 0, 'text':...
# 194491  [{'severity': 'major', 'start_idx': 0, 'text':...
# 194492  [{'severity': 'major', 'start_idx': 0, 'text':...
# 194497  [{'severity': 'major', 'start_idx': 75, 'text'...
#
# [1795 rows x 6 columns]

# %%
df_samp.loc[(df_samp.errors.apply(lambda x: len(x))==0)].iloc[:, 2:4]
# Out:
#                                                       ENG  \
# 547124  "Where any ground prescribed by Presidential D...
# 547125  The standard remuneration under Article 3 (2) ...
# 547126  Where an artist falls under any of the followi...
# 547127  Where a worker falls under any of the followin...
# 394152  The purpose of this Act is to facilitate forei...
# ...                                                   ...
# 78001   The right to receive payments of principal and...
# 78006   Any person requested to provide materials rela...
# 78007   Where necessary to formulate and carry out pol...
# 406361  Notwithstanding paragraph (3), a workplace cre...
# 406362  When providing the welfare services under para...
#
#                                                       KOR
# 547124  법 제3조제1항에서 "대통령령으로 정하는 사유에 해당하는 경우"란 다음 각 호의 어...
# 547125  법 제3조제2항(법 제48조의2제8항제2호 및 제48조의3제8항제2호에서 준용하는 ...
# 547126  예술인이 다음 각 호의 어느 하나에 해당하는 경우 법 제48조의2제8항제2호에서 준...
# 547127  노무제공자가 다음 각 호의 어느 하나에 해당하는 경우 법 제48조의3제8항제2호에서...
# 394152  이 법은 경제자유구역의 지정 및 운영을 통하여 외국인투자기업 및 국내복귀기업의 경영...
# ...                                                   ...
# 78001   국채의 원금 및 이자를 받을 권리는 5년간 행사하지 아니하면 시효(시효)의 완성으로...
# 78006   제1항에 따라 국채 관련 자료의 제출을 요청받은 자는 특별한 사유가 없으면 요청에 ...
# 78007   기획재정부장관은 국채시장에 관한 정책의 수립·운영에 필요한 경우에는 관계 중앙행정기...
# 406361  제3항의 규정에 불구하고 제12조제1항제2호의 직장조합 및 동항제3호 라목의 단체조...
# 406362  조합이 제1항의 규정에 의한 복지사업을 실시하는 경우에는 이용자에게 비용을 부담시킬...
#
# [16781 rows x 2 columns]

# %% [markdown]
# ## 나중에

# %%
pat = r"\"[ㄱ-ㅎ|가-힣]+\""
quote_comp = re.compile(pat)
quote_words = df_samp.loc[df_samp.KOR.str.contains(pat)].KOR.apply(lambda x: quote_comp.findall(x))
quote_words
# Out:
# 547121                    ["단기예술인"]
# 547123                  ["단기노무제공자"]
# 394156                   ["경제자유구역"]
# 394158                      ["외국인"]
# 394159                  ["외국인투자기업"]
#                     ...
# 194419    ["위원장", "재심사위원회", "소위원회"]
# 194455             ["진찰", "특진의료기관"]
# 416399        ["의결권권유자", "의결권피권유자"]
# 194470             ["근로자", "진폐근로자"]
# 194496         ["근로자", "특수형태근로종사자"]
# Name: KOR, Length: 1716, dtype: object

# %%
quword4 = quote_words[quote_words.apply(lambda x: max(list(map(lambda k: len(k), x)))) > 8]

# %%
qw_srs = quword4.apply(lambda x: sorted(x, key=lambda k: len(k), reverse=True)[0].strip('"').rstrip("등"))
sort_index = qw_srs.apply(len).sort_values().index
qw_srs[sort_index]
# Out:
# 548555                출산전후급여
# 81365                 대부중개업자
# 397510                은행지주회사
# 207755                지정의료기관
# 83487                 여신금융기관
#                  ...
# 422493          주택담보노후연금보증채무
# 418500         금융투자상품거래청산업인가
# 416776        외국금융투자상품거래청산회사
# 556053        산업재해보상보험재심사위원회
# 519095    부당이득징수금체납정보공개심의위원회
# Name: KOR, Length: 409, dtype: object

# %%
origin_text = list(set(list(qw_srs.values)))
origin_text
# origin_text

# %% [markdown]
# ## 다른 오류 생성

# %%
df_samp.loc[df_samp.errors.apply(len)==0].shape[0]
# Out:
# 3903

# %%
not_yet_index = df_samp.loc[df_samp.errors.apply(len)==0].index

# %%
temp = df_samp.loc[not_yet_index]
temp.loc[temp.curHyp.str.contains("할 수 있다")].iloc[:, 2:4]

# %%
pattern = r"[\d]+조[^\항]*[\d]+항"
hangho = re.compile(pattern)
txtx = "집합투자업자는 제80조제4항 및 제86조제1항에도 불구하고 법 제81조제1항 단서 및 제234조제4항에 따라 상장지수집합투자기구(투자자 보호 등을 고려하여 금융위원회가 정하여 고시하는 상장지수집합투자기구에 한정한다)의 집합투자재산을 다음 각 호의 방법으로 운용할 수 있다."
sres = hangho.search(txtx)
print(sres)
fnum = txtx[sres.span()[0]]
snum = txtx[sres.span()[1]-2]
print(fnum, snum)
# Out:
# <re.Match object; span=(9, 15), match='80조제4항'>
# 8 4

# %%
def make_dict(df):
    output_json = dict()
    output_json["data"] = []
    for i in df.index:
        base_form = {"category": None, "en": None, "errs": None, "hyp": None, "ko": None, "law_name": None}
        if len(df.loc[i, "errors"])==0:
            continue
        base_form["category"] = df.loc[i, "category"]
        base_form["en"] = df.loc[i, "ENG"]
        base_form["errs"] = df.loc[i, "errors"]
        base_form["hyp"] = df.loc[i, "curHyp"]
        base_form["ko"] = df.loc[i, "KOR"]
        base_form["law_name"] = df.loc[i, "lawName"]
        output_json["data"].append(base_form)
    return output_json

rrrr = make_dict(df_samp)

# %%
with open(os.path.join(gdrive_path, "data_0823.json"), "w") as f:
  json.dump(rrrr, f, ensure_ascii=False, indent=4)
